# %%
import os
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
os.chdir(PROJECT_ROOT)

print("Working directory set to:", os.getcwd())
# Out:
# Working directory set to: /Users/daniehbenotman/Desktop/intelligent-support-ticket-automation

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path().resolve().parent 
sys.path.append(str(PROJECT_ROOT))

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from src.preprocessing.text_preprocessing import load_data
df = load_data()
df.head()
# Out:
#    ticket_id  ... true_priority
# 0  TKT000001  ...            P3
# 1  TKT000002  ...            P4
# 2  TKT000003  ...            P4
# 3  TKT000004  ...            P3
# 4  TKT000005  ...            P3
#
# [5 rows x 7 columns]
